# %% [markdown]
# # Python Assignment 1

# %%
a= ("Hello")
b= str(input("Enter your Name: "))
print (a, b)
# Out:
# Enter your Name: Meganathan Ravi
# Hello Meganathan Ravi

# %%
c= ("Welcome to Python Programming")
print (a, b, c)
# Out:
# Hello Meganathan Ravi Welcome to Python Programming

# %%
c= ("Welcome to Python Programming")

# %% [markdown]
# # String Slicing and Indexing:

# %%
c[0]
# Out:
# 'W'

# %%
c[-1]
# Out:
# 'g'

# %%
c[:5]
# Out:
# 'Welco'

# %%
c[-11:]
# Out:
# 'Programming'

# %%
c[::-1]
# Out:
# 'gnimmargorP nohtyP ot emocleW'

# %%
c[10:17]
# Out:
# ' Python'

# %% [markdown]
# #String Methods

# %%
m = ("Python beginner tutorial")
m
# Out:
# 'Python beginner tutorial'

# %%
m.upper()
# Out:
# 'PYTHON BEGINNER TUTORIAL'

# %%
m.lower()
# Out:
# 'python beginner tutorial'

# %%
m.capitalize()
# Out:
# 'Python beginner tutorial'

# %%
m.count("t")
# Out:
# 3

# %%
m.replace("Python", "Machine Learning")
# Out:
# 'Machine Learning beginner tutorial'

# %%
print(m)
# Out:
# Python beginner tutorial

# %% [markdown]
# # Tuples

# %%
t1 =(10, 20, 30)
t2 =(40, 50, 60)

# %%
print (type(t1))
# Out:
# <class 'tuple'>

# %%
print (type(t2))
# Out:
# <class 'tuple'>

# %%
t_combine = t1+t2
print (t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
t_combine*3
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
t_combine[2]
# Out:
# 30

# %%
t_combine[:3]
# Out:
# (10, 20, 30)

# %%
len(t_combine)
# Out:
# 6

# %%
t_combine[3:]
# Out:
# (40, 50, 60)
